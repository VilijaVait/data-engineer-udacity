# %% [markdown]
# # Sparkify: import data from AWS S3 to Postgres local instance

# %% [markdown]
# ### Extract .CSV data from AWS S3 for each table in a schema into Pandas dataframes and then load it from Pandas dataframes to local instance of Postgres, plus option to examine/transform data (between extraction and loading) in Pandas dataframes

# %%
import psycopg2   # python library to be used for connection to Postgres, and basic commands like 
                  # creating/dropping databases and tables, executing SQL queries
import s3fs       # python library to be used for reading files into Pandas from S3
import pandas as pd
from sql_queries import *  #import sql queries for creation of all tables/deletion of all tables in the database

# %%
# these libraries to be used for authentication with AWS, connecting to S3 and listing of resources in S3
import configparser
import os
import boto3

# %%
# python library to be used for connection to Postgres, and specifically writing Pandas dataframes to Postgres,
# and inspecting tables (and variable datatypes) within Postgres 
from sqlalchemy import create_engine, inspect

# %%
# Connect to the database (or any database) within your Postgres database
conn = psycopg2.connect("host=localhost dbname=sparkify user=postgres password=supergirl")
conn.autocommit = True
cur = conn.cursor()

# %%
# Create new database for the to-be imported data, if it does not exist, and connect to this database 
# (instead of initial one)

#cur.execute("""
#            CREATE DATABASE sparkify;
#            """
#           )

# %%
# set properties of Pandas dataframes, and print all `create_table_queries` imported from sql_queries file, in order to 
# examine them before execution
pd.set_option('max_colwidth', 800)
df = pd.DataFrame({'queries':create_table_queries})
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                queries
# 0  CREATE TABLE IF NOT EXISTS songplays (\n                            songplay_id SERIAL PRIMARY KEY, \n                            start_time timestamp NOT NULL, \n                            user_id int NOT NULL, \n                            level varchar, \n                            song_id varchar, \n                            artist_id varchar,\n                            title varchar,\n                            name varchar,\n                            duration float,\n                            session_id int NOT NULL, \n                            location text, \n                            user_agent text);\n
# 1                                                                                                                                                                                                                                                                                                                                                CREATE TABLE IF NOT EXISTS users (\n                        user_id int, \n                        first_name varchar, \n                        last_name varchar, \n                        gender varchar, \n                        level varchar,\n                        PRIMARY KEY (user_id, level));\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                 CREATE TABLE IF NOT EXISTS songs (\n                        song_id varchar PRIMARY KEY, \n                        title varchar, \n                        artist_id varchar, \n                        year int, \n                        duration float);\n
# 3                                                                                                                                                                                                                                                                                                                                 CREATE TABLE IF NOT EXISTS artists (\n                          artist_id varchar, \n                          name varchar, \n                          location text, \n                          latitude float, \n                          longitude float,\n                          PRIMARY KEY (artist_id, name));\n
# 4                                                                                                                                                                                                                                                                                                                                  CREATE TABLE IF NOT EXISTS time (\n                        start_time timestamp PRIMARY KEY, \n                        hour int, \n                        day int, \n                        week int, \n                        month int, \n                        year int, \n                        weekday varchar);\n

# %%
# drop all tables (if you have any tables created prior or are reruning the download)
for query in drop_table_queries:
    cur.execute(query)

# %%
# create all tables required for the new schema, for which data is to be imported from S3
for query in create_table_queries:
    cur.execute(query)

# %% [markdown]
# ### Import data from S3 bucket into Pandas dataframe

# %% [markdown]
# #### Get AWS credentials

# %%
# get AWS credentials from `db.cfg` file saved in the same directory as the notebook
config = configparser.ConfigParser()
config.read('db.cfg')

os.environ['AWS_ACCESS_KEY_ID']=config['AWS']['AWS_ACCESS_KEY_ID']
os.environ['AWS_SECRET_ACCESS_KEY']=config['AWS']['AWS_SECRET_ACCESS_KEY']

# %% [markdown]
# #### Create S3 boto3 resource

# %%
s3 = boto3.resource('s3',
                       region_name="us-east-2",
                       aws_access_key_id=config['AWS']['AWS_ACCESS_KEY_ID'],
                       aws_secret_access_key=config['AWS']['AWS_SECRET_ACCESS_KEY']
                   )

# %% [markdown]
# #### Function

# %%
"""
read_table_data_from_s3 function uses given S3 path, S3 bucket name and then filters with S3 bucket folder (i.e. prefix) 
to obtain all files (inc. subfolders) in the bucket with a given prefix, reads those files into dataframes, appends to 
master list of data frames and then concatinates that list into one master dataframe.

For effective read of data, you will want for data in to-be table in Postgres to be contained in separate S3 folder 
(i.e. prefix).

Input:  S3 path (string), S3 bucket name (string), S3 bucket folder i.e. prefix (string)
Output: Pandas Dataframe with data from specified S3 bucket/folder
"""
def read_table_data_from_s3(path, s3bucket_name, prefix):
    dfs = []
    count = 0
    s3bucket =  s3.Bucket(s3bucket_name)
    
    for i, obj in enumerate(s3bucket.objects.filter(Prefix=prefix),start=1):
        count += 1
        try: 
            dfs.append(pd.read_csv(path+obj.key, sep = ',', header=0))
            if count % 10 == 0:
                print("{} - read file {}".format(i,path+obj.key))
        except:
            # list files that were not read (can be identified and examined why skipped)
            print("{} - skipping {}".format(i,path+obj.key))
            pass

    # Concatenate all data into one DataFrame
    df = pd.concat(dfs, ignore_index=True)   
    return df

# %%
# Run read_table_data_from_s3 on sample data from given S3 bucket, where each to-be table data will be contained in five
# separate folders ['time', 'users', 'songs', 'artists', 'songplays']
# Save each table as key:value pair (table name:dataframe) in dictionary `df_dict` containting the five key:value pairs, 
# one for each table

path = 's3://udacity-sparkify-out/'
s3bucket_name =  'udacity-sparkify-out'
prefix_ls = ['time', 'users', 'songs', 'artists', 'songplays']

df_dict = {}

for prefix in prefix_ls:
    df_dict[prefix] = read_table_data_from_s3(path, s3bucket_name, prefix)
# Out:
# 1 - skipping s3://udacity-sparkify-out/time/_SUCCESS
# 10 - read file s3://udacity-sparkify-out/time/part-00008-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 20 - read file s3://udacity-sparkify-out/time/part-00018-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 30 - read file s3://udacity-sparkify-out/time/part-00028-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 40 - read file s3://udacity-sparkify-out/time/part-00038-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 50 - read file s3://udacity-sparkify-out/time/part-00048-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 60 - read file s3://udacity-sparkify-out/time/part-00058-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 70 - read file s3://udacity-sparkify-out/time/part-00068-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 80 - read file s3://udacity-sparkify-out/time/part-00078-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 90 - read file s3://udacity-sparkify-out/time/part-00088-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 100 - read file s3://udacity-sparkify-out/time/part-00098-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 110 - read file s3://udacity-sparkify-out/time/part-00108-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 120 - read file s3://udacity-sparkify-out/time/part-00118-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 130 - read file s3://udacity-sparkify-out/time/part-00128-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 140 - read file s3://udacity-sparkify-out/time/part-00138-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 150 - read file s3://udacity-sparkify-out/time/part-00148-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 160 - read file s3://udacity-sparkify-out/time/part-00158-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 170 - read file s3://udacity-sparkify-out/time/part-00168-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 180 - read file s3://udacity-sparkify-out/time/part-00178-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 190 - read file s3://udacity-sparkify-out/time/part-00188-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 200 - read file s3://udacity-sparkify-out/time/part-00198-ebe341b7-ed90-4c12-91e0-4a1316e8fc73-c000.csv
# 1 - skipping s3://udacity-sparkify-out/users/_SUCCESS
# 2 - skipping s3://udacity-sparkify-out/users/part-00000-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 10 - read file s3://udacity-sparkify-out/users/part-00023-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 20 - read file s3://udacity-sparkify-out/users/part-00040-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 30 - read file s3://udacity-sparkify-out/users/part-00058-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 40 - read file s3://udacity-sparkify-out/users/part-00077-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 50 - read file s3://udacity-sparkify-out/users/part-00111-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 60 - read file s3://udacity-sparkify-out/users/part-00136-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 70 - read file s3://udacity-sparkify-out/users/part-00161-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 80 - read file s3://udacity-sparkify-out/users/part-00184-51707e09-c722-4f99-a610-3464f2ae0a06-c000.csv
# 1 - skipping s3://udacity-sparkify-out/songs/_SUCCESS
# 10 - read file s3://udacity-sparkify-out/songs/part-00008-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 20 - read file s3://udacity-sparkify-out/songs/part-00018-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 30 - read file s3://udacity-sparkify-out/songs/part-00028-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 40 - read file s3://udacity-sparkify-out/songs/part-00038-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 50 - read file s3://udacity-sparkify-out/songs/part-00048-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 60 - read file s3://udacity-sparkify-out/songs/part-00058-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 70 - read file s3://udacity-sparkify-out/songs/part-00068-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 80 - read file s3://udacity-sparkify-out/songs/part-00078-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 90 - read file s3://udacity-sparkify-out/songs/part-00088-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 100 - read file s3://udacity-sparkify-out/songs/part-00098-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 110 - read file s3://udacity-sparkify-out/songs/part-00108-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 120 - read file s3://udacity-sparkify-out/songs/part-00118-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 130 - read file s3://udacity-sparkify-out/songs/part-00128-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 140 - read file s3://udacity-sparkify-out/songs/part-00138-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 150 - read file s3://udacity-sparkify-out/songs/part-00148-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 160 - read file s3://udacity-sparkify-out/songs/part-00158-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 170 - read file s3://udacity-sparkify-out/songs/part-00168-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 180 - read file s3://udacity-sparkify-out/songs/part-00178-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 190 - read file s3://udacity-sparkify-out/songs/part-00188-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 200 - read file s3://udacity-sparkify-out/songs/part-00198-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 210 - read file s3://udacity-sparkify-out/songs/part-00208-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 220 - read file s3://udacity-sparkify-out/songs/part-00218-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 230 - read file s3://udacity-sparkify-out/songs/part-00228-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 240 - read file s3://udacity-sparkify-out/songs/part-00238-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 250 - read file s3://udacity-sparkify-out/songs/part-00248-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 260 - read file s3://udacity-sparkify-out/songs/part-00258-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 270 - read file s3://udacity-sparkify-out/songs/part-00268-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 280 - read file s3://udacity-sparkify-out/songs/part-00278-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 290 - read file s3://udacity-sparkify-out/songs/part-00288-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 300 - read file s3://udacity-sparkify-out/songs/part-00298-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 310 - read file s3://udacity-sparkify-out/songs/part-00308-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 320 - read file s3://udacity-sparkify-out/songs/part-00318-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 330 - read file s3://udacity-sparkify-out/songs/part-00328-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 340 - read file s3://udacity-sparkify-out/songs/part-00338-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 350 - read file s3://udacity-sparkify-out/songs/part-00348-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 360 - read file s3://udacity-sparkify-out/songs/part-00358-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 370 - read file s3://udacity-sparkify-out/songs/part-00368-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 380 - read file s3://udacity-sparkify-out/songs/part-00378-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 390 - read file s3://udacity-sparkify-out/songs/part-00388-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 400 - read file s3://udacity-sparkify-out/songs/part-00398-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 410 - read file s3://udacity-sparkify-out/songs/part-00408-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 420 - read file s3://udacity-sparkify-out/songs/part-00418-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 430 - read file s3://udacity-sparkify-out/songs/part-00428-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 440 - read file s3://udacity-sparkify-out/songs/part-00438-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 450 - read file s3://udacity-sparkify-out/songs/part-00448-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 460 - read file s3://udacity-sparkify-out/songs/part-00458-2b7f36fa-e144-4fe2-b8e1-fe1a5aa368d3-c000.csv
# 1 - skipping s3://udacity-sparkify-out/artists/_SUCCESS
# 10 - read file s3://udacity-sparkify-out/artists/part-00008-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 20 - read file s3://udacity-sparkify-out/artists/part-00018-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 30 - read file s3://udacity-sparkify-out/artists/part-00028-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 40 - read file s3://udacity-sparkify-out/artists/part-00038-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 50 - read file s3://udacity-sparkify-out/artists/part-00048-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 60 - read file s3://udacity-sparkify-out/artists/part-00058-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 70 - read file s3://udacity-sparkify-out/artists/part-00068-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 80 - read file s3://udacity-sparkify-out/artists/part-00078-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 87 - skipping s3://udacity-sparkify-out/artists/part-00085-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 90 - read file s3://udacity-sparkify-out/artists/part-00088-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 100 - read file s3://udacity-sparkify-out/artists/part-00098-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 110 - read file s3://udacity-sparkify-out/artists/part-00108-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 120 - read file s3://udacity-sparkify-out/artists/part-00118-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 130 - read file s3://udacity-sparkify-out/artists/part-00128-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 140 - read file s3://udacity-sparkify-out/artists/part-00138-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 150 - read file s3://udacity-sparkify-out/artists/part-00148-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 160 - read file s3://udacity-sparkify-out/artists/part-00158-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 170 - read file s3://udacity-sparkify-out/artists/part-00168-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 180 - read file s3://udacity-sparkify-out/artists/part-00178-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 190 - read file s3://udacity-sparkify-out/artists/part-00188-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 200 - read file s3://udacity-sparkify-out/artists/part-00198-a43742b6-3a78-45a7-9339-57919af708aa-c000.csv
# 1 - skipping s3://udacity-sparkify-out/songplays/_SUCCESS

# %% [markdown]
# ### Check data in dataframes

# %%
# Examine shape of each dataframe that was read-in
for key in df_dict.keys():
    print("Table: {} rows: {} cols: {}".format(key, df_dict[key].shape[0],df_dict[key].shape[1]))
# Out:
# Table: time rows: 6813 cols: 7
# Table: users rows: 104 cols: 5
# Table: songs rows: 14896 cols: 5
# Table: artists rows: 9975 cols: 5
# Table: songplays rows: 6820 cols: 12

# %%
# Check sample values of each dataframe
for key in df_dict.keys():
    print(df_dict[key].columns)
    print(df_dict[key].sample().values)
    print()
# Out:
# Index(['start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday'], dtype='object')
# [['2018-11-24T16:52:10.000Z' 16 24 47 11 2018 'Saturday']]
#
# Index(['user_id', 'first_name', 'last_name', 'gender', 'level'], dtype='object')
# [[55 'Martin' 'Johnson' 'M' 'free']]
#
# Index(['song_id', 'title', 'artist_id', 'year', 'duration'], dtype='object')
# [['SOWKBRB12A8C140063' 'Kill The Messenger' 'ARJZZXN1187FB4D526' 2007
#   232.72444]]
#
# Index(['artist_id', 'name', 'location', 'latitude', 'longitude'], dtype='object')
# [['ARYWKWZ1187FB53C75' 'Daron Norwood' 'Lubbock, TX' 33.59233 -101.85587]]
#
# Index(['songplay_id', 'start_time', 'user_id', 'level', 'song_id', 'artist_id',
#        'title', 'name', 'duration', 'session_id', 'location', 'user_agent'],
#       dtype='object')
# [[6124 '2018-11-28T22:28:11.000Z' 24 'paid' nan nan
#   'Redline (2009 Digital Remaster)' 'Saxon' 217.15546 984
#   'Lake Havasu City-Kingman, AZ'
#   '\\Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/36.0.1985.125 Safari/537.36\\""']]

# %%
# Examine first five values of a specific table
df_dict['songplays'].head()
# Out:
#    songplay_id                start_time  user_id level             song_id  \
# 0            1  2018-11-01T21:01:46.000Z        8  free                 NaN
# 1            2  2018-11-01T21:05:52.000Z        8  free                 NaN
# 2            3  2018-11-01T21:08:16.000Z        8  free                 NaN
# 3            4  2018-11-01T21:11:13.000Z        8  free  SOEIQUY12AF72A086A
# 4            5  2018-11-01T21:17:33.000Z        8  free                 NaN
#
#             artist_id                         title               name  \
# 0                 NaN                  You Gotta Be            Des'ree
# 1                 NaN                       Flat 55            Mr Oizo
# 2                 NaN  Quem Quiser Encontrar O Amor         Tamba Trio
# 3  ARHUC691187B9AD27F                     Eriatarka     The Mars Volta
# 4                 NaN               Becoming Insane  Infected Mushroom
#
#     duration  session_id                     location  \
# 0  246.30812         139  Phoenix-Mesa-Scottsdale, AZ
# 1  144.03873         139  Phoenix-Mesa-Scottsdale, AZ
# 2  177.18812         139  Phoenix-Mesa-Scottsdale, AZ
# 3  380.42077         139  Phoenix-Mesa-Scottsdale, AZ
# 4  440.26730         139  Phoenix-Mesa-Scottsdale, AZ
#
#                                                                                                          user_agent
# 0  \Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/35.0.1916.153 Safari/537.36\""
# 1  \Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/35.0.1916.153 Safari/537.36\""
# 2  \Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/35.0.1916.153 Safari/537.36\""
# 3  \Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/35.0.1916.153 Safari/537.36\""
# 4  \Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML like Gecko) Chrome/35.0.1916.153 Safari/537.36\""

# %%
# Check data types, counts/nulls for each column in dataframe
for key in df_dict.keys():
    df_dict[key].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6813 entries, 0 to 6812
# Data columns (total 7 columns):
# start_time    6813 non-null object
# hour          6813 non-null int64
# day           6813 non-null int64
# week          6813 non-null int64
# month         6813 non-null int64
# year          6813 non-null int64
# weekday       6813 non-null object
# dtypes: int64(5), object(2)
# memory usage: 372.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 5 columns):
# user_id       104 non-null int64
# first_name    104 non-null object
# last_name     104 non-null object
# gender        104 non-null object
# level         104 non-null object
# dtypes: int64(1), object(4)
# memory usage: 4.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14896 entries, 0 to 14895
# Data columns (total 5 columns):
# song_id      14896 non-null object
# title        14896 non-null object
# artist_id    14896 non-null object
# year         14896 non-null int64
# duration     14896 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 582.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9975 entries, 0 to 9974
# Data columns (total 5 columns):
# artist_id    9975 non-null object
# name         9975 non-null object
# location     5193 non-null object
# latitude     3423 non-null float64
# longitude    3423 non-null float64
# dtypes: float64(2), object(3)
# memory usage: 389.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6820 entries, 0 to 6819
# Data columns (total 12 columns):
# songplay_id    6820 non-null int64
# start_time     6820 non-null object
# user_id        6820 non-null int64
# level          6820 non-null object
# song_id        319 non-null object
# artist_id      319 non-null object
# title          6820 non-null object
# name           6820 non-null object
# duration       6820 non-null float64
# session_id     6820 non-null int64
# location       6820 non-null object
# user_agent     6820 non-null object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 639.5+ KB

# %%
# Cleaning up duplicates in 'artists' table -- AIM TO KEEP UNIQUE artist_id and name unique (it seems that same artist_id 
# was often used if the same artist is used in combination with other artists in name)

# Show all duplicates that have no latitude/longitude information
df_dict['artists'][(df_dict['artists'][['artist_id']].duplicated(keep=False)&df_dict['artists']['longitude'].isnull())]
# Out:
#                artist_id  \
# 6     ARYEBQC1187FB5ACD9
# 22    ARZ1F401187FB5B0A3
# 25    ARKC83D1187B9AB367
# 34    ARTHSAE12131B4B70A
# 43    ARWD3QD1187FB51DC0
# 64    ARKIXC01187B992786
# 106   ARUNHUJ1187FB4C13E
# 121   ARCXKY91187B9ACA99
# 134   ARY0XD81187FB5CF38
# 155   ARKTSTP1187FB51C66
# 188   ARBIVRF1187FB3F570
# 190   AROGAPH1187B98CF9C
# 196   AR4MMMF1187B99AB91
# 248   AR65UIK1187B9AC580
# 268   ARDSWIE1187FB39056
# 277   ARIGPNM1187B98C744
# 284   AR1QF001187B9B2B9F
# 313   ARL1A8E1187FB596F2
# 374   AROVZAK1187B9BA3F7
# 401   ARC0ANR1187FB4E291
# 424   AROBOIW11F4C84748F
# 442   AROEQW91187FB58663
# 446   ARPDVPJ1187B9ADBE9
# 455   AR2ZNXL1187B9B87A1
# 472   ARFEOJM1187B9AA3B8
# 473   AR551ZU1187B9A3E50
# 483   ARQBWLU1187B99ECFE
# 489   ARHTAPO1187FB5AADE
# 494   ARS65Z91187FB43D7F
# 543   ARMKODX11F50C4BD1B
# ...                  ...
# 9424  ARNULK21187FB46537
# 9428  ARHLGDG11F4C846A37
# 9430  ARJGAUD1187FB505DA
# 9437  AR9GUZF1187FB4D1BC
# 9469  AREV2491187B9B017E
# 9472  AR615ZF1187FB4A4B0
# 9474  ARFACVS1187B98C226
# 9492  ARPDVPJ1187B9ADBE9
# 9525  ARC0ANR1187FB4E291
# 9540  ARZXTEY1187B9997A7
# 9549  ARDI88R1187B98DAB2
# 9582  ARUWLCL1187FB549B8
# 9602  AR8L6W21187B9AD317
# 9657  ARZQ7QA1187B9AD08B
# 9679  ARBU9P41187FB48686
# 9681  ARW1BRR1187B996332
# 9693  ARI9LZI1187B9A3A53
# 9719  ARQZINN11F4C84076C
# 9730  AR2WN631187B99DA0B
# 9750  AR1XD261187B9ACF9B
# 9794  ARMCJVK11F4C84373E
# 9797  AR10USD1187B99F3F1
# 9804  ARKTSTP1187FB51C66
# 9806  AR189B91187B9B8D9C
# 9807  ARV38Z81187B98E608
# 9853  AR2AIW411C8A42C5C2
# 9870  AR07SOR1187FB46179
# 9882  ARJO8W91187B9AB734
# 9910  AROXIDV1187B9B222F
# 9949  AR6PETN1187B998AA2
#
#                                                          name  \
# 6                                     The Devin Townsend Band
# 22                                   Baaba Maal_ Mansour Seck
# 25                                                 Mark Lowry
# 34    Sir Simon Rattle/Berliner Philharmoniker/Guy Braunstein
# 43                    Katherine Jenkins [with Amaury Vassili]
# 64                 Dan Zanes & Friends Featuring Father Goose
# 106                                          The Black Ghosts
# 121         Diana Krall / The Clayton-Hamilton Jazz Orchestra
# 134                                   Mustafa Sandal / Gülcan
# 155                                        The Fort Knox Five
# 188                            Dale Watson and His Lone Stars
# 190                                                   Benabar
# 196                                            Grant McLennan
# 248                                              Naçao Zumbi´
# 268                                                Gang Starr
# 277                                                     Kelis
# 284                                              Dave Brubeck
# 313                                                 The Heavy
# 374                                           The New Edition
# 401                                                   Spinvis
# 424                             Swingin' Utters/Youth Brigade
# 442                                        Sebastien Schuller
# 446                            Usher featuring Jermaine Dupri
# 455                                               Eddi Reader
# 472                                          Sisqo / Dru Hill
# 473                                              Paul Carrack
# 483                                              Space Buddha
# 489                                                      1001
# 494                                                Marcelo D2
# 543                                                   Ramones
# ...                                                       ...
# 9424                     Grandmaster Flash & The Furious Five
# 9428                             Lil Jon & The East Side Boyz
# 9430                                                   Lan Ge
# 9437                                            10000 Maniacs
# 9469                            Mobb Deep featuring Nate Dogg
# 9472                                            Mistah F.A.B.
# 9474                                        Pat Metheny Group
# 9492                                                    Usher
# 9525                                      Spinvis / Vinkenoog
# 9540         Juelz Santana / Freekey Zeekey / Monique Garnett
# 9549                                               Foxy Brown
# 9582                                   Yamandu + Dominguinhos
# 9602                                Diana Ross & The Supremes
# 9657                                                   Prince
# 9679                     Bobby Helms & The Anita Kerr Singers
# 9681                                           Voyager Series
# 9693                                                  4 Wings
# 9719                                    Echo And The Bunnymen
# 9730                                        Randy Rogers Band
# 9750                                 Nick Cave & Warren Ellis
# 9794                                           Fort Knox Five
# 9797                                    Tweeterfriendly Music
# 9804                                 Bobby Hughes Combination
# 9806                                            Cerati-Melero
# 9807                                                 The Jets
# 9853                                 Jiggy Dje feat. FS Green
# 9870                                        The Goo Goo Dolls
# 9882                           Mystic Revelation of Rastafari
# 9910                                               HAMMERFALL
# 9949                           SAUCE MONEY FEATURING MAVERICK
#
#                          location  latitude  longitude
# 6                             NaN       NaN        NaN
# 22                            NaN       NaN        NaN
# 25                            NaN       NaN        NaN
# 34                            NaN       NaN        NaN
# 43             Neath, South Wales       NaN        NaN
# 64                            NaN       NaN        NaN
# 106                        London       NaN        NaN
# 121               Nanaimo, Canada       NaN        NaN
# 134                           NaN       NaN        NaN
# 155                           NaN       NaN        NaN
# 188                            AL       NaN        NaN
# 190                           NaN       NaN        NaN
# 196                           NaN       NaN        NaN
# 248                           NaN       NaN        NaN
# 268        Boston, Massachusettes       NaN        NaN
# 277                    Harlem, NY       NaN        NaN
# 284                   Concord, CA       NaN        NaN
# 313                           NaN       NaN        NaN
# 374                    Boston, MA       NaN        NaN
# 401                           NaN       NaN        NaN
# 424                           NaN       NaN        NaN
# 442                  Paris FRANCE       NaN        NaN
# 446                   Atlanta, GA       NaN        NaN
# 455                           NaN       NaN        NaN
# 472                 Baltimore, MD       NaN        NaN
# 473                           NaN       NaN        NaN
# 483                           NaN       NaN        NaN
# 489   Leyton, East End de Londres       NaN        NaN
# 494                           NaN       NaN        NaN
# 543                           NaN       NaN        NaN
# ...                           ...       ...        ...
# 9424                          NaN       NaN        NaN
# 9428                  Atlanta, GA       NaN        NaN
# 9430                          NaN       NaN        NaN
# 9437                Jamestown, NY       NaN        NaN
# 9469             Queensbridge, NY       NaN        NaN
# 9472                   Oakland CA       NaN        NaN
# 9474                          NaN       NaN        NaN
# 9492                  Atlanta, GA       NaN        NaN
# 9525                          NaN       NaN        NaN
# 9540        New York, NY [Harlem]       NaN        NaN
# 9549                          NaN       NaN        NaN
# 9582                          NaN       NaN        NaN
# 9602                  Detroit, MI       NaN        NaN
# 9657              Minneapolis, MN       NaN        NaN
# 9679              Bloomington, IN       NaN        NaN
# 9681                          NaN       NaN        NaN
# 9693                          NaN       NaN        NaN
# 9719                          NaN       NaN        NaN
# 9730                          NaN       NaN        NaN
# 9750                          NaN       NaN        NaN
# 9794                          NaN       NaN        NaN
# 9797  Burlington, Ontario, Canada       NaN        NaN
# 9804                          NaN       NaN        NaN
# 9806                          NaN       NaN        NaN
# 9807                          NaN       NaN        NaN
# 9853                          NaN       NaN        NaN
# 9870                  Buffalo, NY       NaN        NaN
# 9882                          NaN       NaN        NaN
# 9910           Gothenburg, Sweden       NaN        NaN
# 9949           BROOKLYN, New York       NaN        NaN
#
# [609 rows x 5 columns]

# %%
# Drop all duplicates that have no latitude/longitude information
df_dict['artists'] = df_dict['artists'][~(df_dict['artists'][['artist_id']].duplicated(keep=False)&df_dict['artists']['longitude'].isnull())]

# %%
# Show all duplicates that have non-unique (artist_id, name) information
df_dict['artists'][df_dict['artists'][['artist_id', 'name']].duplicated(keep=False)].sort_values('artist_id')
# Out:
#                artist_id                name                         location  \
# 5874  ARBFQAE1187FB3E957     Stephanie Mills           LAWRENCEVILLE, Georgia
# 7315  ARBFQAE1187FB3E957     Stephanie Mills                     Brooklyn, NY
# 4154  ARI0PUX1187FB3F215         Maxi Priest               Great Britain / UK
# 4477  ARI0PUX1187FB3F215         Maxi Priest        Lewisham, London, England
# 3318  ARNMHWR11F4C83B384       Kingston Trio                    Palo Alto, CA
# 9718  ARNMHWR11F4C83B384       Kingston Trio                          Vermont
# 5638  ARQT8QM1187FB3E3CB            The Bats        Christchurch, New Zealand
# 6660  ARQT8QM1187FB3E3CB            The Bats           Cambridge, New Zealand
# 5586  ARV5VTU1187B991858  The Northern Pikes                          Florida
# 9656  ARV5VTU1187B991858  The Northern Pikes  Saskatoon, Saskatchewan, Canada
#
#       latitude  longitude
# 5874  33.95246  -83.98799
# 7315  40.65507  -73.94888
# 4154  54.31392   -2.23218
# 4477  54.31392   -2.23218
# 3318  37.44466 -122.16079
# 9718  43.87165  -72.45165
# 5638 -43.53131  172.63730
# 6660 -37.89306  175.47131
# 5586  50.94165    6.95505
# 9656  52.13050 -106.65931

# %%
# Drop all of "last" duplicates that have non-unique (artist_id, name) information

df_dict['artists'] = df_dict['artists'][~(df_dict['artists'][['artist_id', 'name']].duplicated(keep='last'))]

# %%
# Check that no duplicates of (artist_id, name) combination remain
df_dict['artists'][df_dict['artists'][['artist_id', 'name']].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [artist_id, name, location, latitude, longitude]
# Index: []

# %% [markdown]
# ### Load data from dataframe to Postgres

# %%
# Connect to Postres database with SQLAlchemy

engine = create_engine('postgresql://postgres:supergirl@localhost:5432/sparkify')
insp = inspect(engine)

# %%
# Write each dataframe residing within the dictionary of dataframes to existing (empty) tables in the database
# Each key (from key: value pair in the dictionary) must correspond to the name of existing table of the database 

table_names = df_dict.keys()

for table in table_names:
    print("Loaded table: {}".format(table))
    df_dict[table].to_sql(table, con=engine, if_exists='append',index=False)
# Out:
# Loaded table: time
# Loaded table: users
# Loaded table: songs
# Loaded table: artists
# Loaded table: songplays

# %%
# Check that all tables were written successfully by examining row counts
for table in table_names:
    query = "SELECT COUNT(*) FROM {};".format(table)
    cur.execute(query)
    print(query)
    print(cur.fetchall())
    print()
# Out:
# SELECT COUNT(*) FROM time;
# [(6813,)]
#
# SELECT COUNT(*) FROM users;
# [(104,)]
#
# SELECT COUNT(*) FROM songs;
# [(14896,)]
#
# SELECT COUNT(*) FROM artists;
# [(9361,)]
#
# SELECT COUNT(*) FROM songplays;
# [(6820,)]

# %%
# Further examine the tables after data was written, that datatypes remained as they were defined when
# tables were created

for table in table_names:
    tb_info = insp.get_columns(table)
    print("*** TABLE: {} ***".format(table))
    print()
    for i in range(len(tb_info)):
        print(tb_info[i]['name'], tb_info[i]['nullable'], tb_info[i]['type'])
        print()
# Out:
# *** TABLE: time ***
#
# start_time False TIMESTAMP WITHOUT TIME ZONE
#
# hour True INTEGER
#
# day True INTEGER
#
# week True INTEGER
#
# month True INTEGER
#
# year True INTEGER
#
# weekday True VARCHAR
#
# *** TABLE: users ***
#
# user_id False INTEGER
#
# first_name True VARCHAR
#
# last_name True VARCHAR
#
# gender True VARCHAR
#
# level False VARCHAR
#
# *** TABLE: songs ***
#
# song_id False VARCHAR
#
# title True VARCHAR
#
# artist_id True VARCHAR
#
# year True INTEGER
#
# duration True DOUBLE PRECISION
#
# *** TABLE: artists ***
#
# artist_id False VARCHAR
#
# name False VARCHAR
#
# location True TEXT
#
# latitude True DOUBLE PRECISION
#
# longitude True DOUBLE PRECISION
#
# *** TABLE: songplays ***
#
# songplay_id False INTEGER
#
# start_time False TIMESTAMP WITHOUT TIME ZONE
#
# user_id False INTEGER
#
# level True VARCHAR
#
# song_id True VARCHAR
#
# artist_id True VARCHAR
#
# title True VARCHAR
#
# name True VARCHAR
#
# duration True DOUBLE PRECISION
#
# session_id False INTEGER
#
# location True TEXT
#
# user_agent True TEXT

# %% [markdown]
# ### Close connection (psycopg2)

# %%
# Close communication with the database
>>> cur.close()
>>> conn.close()
